# %%
from logbook import Logbook
from custom_classes import Datetime
logbook = Logbook()
# Out:
# this week's logbook already generated

# %% [markdown]
# ### Week 1

# %%
Feb16 = logbook.write('''Today is the beginning of MSIB program, at this day I atended national onboarding program 
                        16 Feb 2021 - National onboarding program for MSIB student 4th generation at 2 PM (WITA)'''
                     ,type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : ['atended', 'msib', 'onboarding']

# %%
Feb17 = logbook.write('''Today i have two schedule from bangkit, that is technical briefing and life path session
                        9:00-11:00 (WITA) - I attended technical briefing for bangkit 2023 students
                        15:00-17:00 (WITA) - I attended life path session for bangkit 2023 students'''
                    ,type_='daily')
# Out:
# number of words is 32 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport1 = logbook.write('''On the first day of this week i attended tha national onboarding program for MSIB
                                batch 4. The next day i attended technical briefing for bangkit 2023 stundents at 9 am. 
                                On the same day, i attended life path session for bangkit 2023 students at 3 pm.
                                This week's activities gave me the spirit to complete the bangkit 2023 program. I also
                                have given dicoding token to acces some classes in dicoding platform. The classes are :
                                "Memulai Dasar Pemrograman untuk Menjadi Pengembang Software", "Pengenalan ke 
                                Logika Pemrograman (Programming Logic 101)" and "Belajar Dasar Git dengan GitHub".
                                I have finished all that classes until sunday at this week''')
# Out:
# number of words is 101 ,should be between 100 - 150 words
# words that may be misspelled : ['dasar', 'stundents', 'msib', 's', 'github', 'menjadi', 'logika', 'belajar', 'pengembang', 'memulai', 'pemrograman', 'pengenalan', 'onboarding']

# %% [markdown]
# ### Week 2

# %%
Feb20 = logbook.write('''11:00 - 12:00 (WITA) - I attended opening session of bangkit 2023 at youtube platform
                        16:30 - 17:30 (WITA) - I attended weekly consultation with my mentor Lusi Aulia Jati 
                        at google meet platform''',
                     type_='daily')
# Out:
# number of words is 25 ,should be between 20 - 50 words
# words that may be misspelled : ['aulia', 'jati']

# %%
Feb21 = logbook.write('''Today i dont have official activy from bangkit but i got new token from dicoding
                        to access new classes, so today's activity is making some progress on that classes''',
                     type_='daily')
# Out:
# number of words is 30 ,should be between 20 - 50 words
# words that may be misspelled : ['s', 'activy']

# %%
Feb22 = logbook.write('''10:00 - 12:00 (WITA) - I attended first meeting of ILT soft skill with instructor 
                        Nathanael Pribady with the topic is "Growth Mindset and The Power of Feedback"''',
                     type_='daily')
# Out:
# number of words is 24 ,should be between 20 - 50 words
# words that may be misspelled : ['pribady', 'nathanael']

# %%
Feb23 = logbook.write('''Today i dont have official activity from bangkit, but the soft skill instructor give us
                        an assignment. So today is making some progress on dicoding classes and the assignment''',
                     type_='daily')
# Out:
# number of words is 29 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Feb24 = logbook.write('''Today i dont have official activity from bangkit. So today still the same with yesterday
                        , and today i have finished all the class on dicoding''',
                     type_='daily')
# Out:
# number of words is 25 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport2 = logbook.write('''This week i attend weekly consultation with mentor at monday 10 am. The weekly consutation
                                ran well and fun, and i think my mentor is a kind person. At tuesday i dont have any activity 
                                from bangkit, but i got an email from dicoding about new class token. At Wednesday, i attend 
                                ILT soft skill with the instructor and he give an assignment
                                about growth mindset. The assignment consist of 10 multiple choice question and 1 essay. 
                                I have answered half of the multiple choice question as for today (Friday, 24 Feb).
                                This week i also have finished all the dicoding classes that given from Tuesday (21 Feb).
                                ''')
# Out:
# number of words is 103 ,should be between 100 - 150 words
# words that may be misspelled : ['consutation']

# %% [markdown]
# ### Week 3

# %%
Feb27 = logbook.write('''Today i dont have official activity from bangkit. But from last week ILT session , the
                        instructor give an assignment. So today i finishing the assignment and submit it''',
                        type_='daily')
# Out:
# number of words is 28 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Feb28 = logbook.write('''Today i only have one schedule, that is weekly consultation with my mentor, kak Lusi
                        9:00-10:00(WITA) - I attended weekly consultation with mentor''',
                        type_='daily')
# Out:
# number of words is 22 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar01 = logbook.write('''Today i only have one schedule, that is ML ILT session with instructor , Mr. Hidayaturrahman
                        14:00-16:00 (WITA) - I attended ML ILT session with the topic "Introduction to Python & Git/GitHub"''',
                     type_='daily')
# Out:
# number of words is 29 ,should be between 20 - 50 words
# words that may be misspelled : ['github', 'mr', 'hidayaturrahman']

# %%
Mar02 = logbook.write('''Today i dont have official activity from bangkit. But from last week i got access to coursera
                        courses. So far , i already finished "Crash Course on Python" and today i continue to next 
                        course "Using Python to Interact with the Operating System" ''',
                        type_='daily')
# Out:
# number of words is 42 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar03 = logbook.write('''Today i have 2 activity from bangkit. One is mandatory and the other one is not mandatory
                        10:00-11:00(WITA) I did the english pre-test from bangkit.
                        16:30-18:00(WITA) I joined guest speaker session #1 at bangkit youtube channel''',
                        type_='daily')
# Out:
# number of words is 35 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport3 = logbook.write('''This week , i attended weekly consultation with mentor , kak Lusi at Tuesday (9 AM). In
                                 the next day (2 PM), i attended ML ILT session with instructor, Hidayaturrahman. We discuss 
                                 about Python and Git/Github at that ILT session. At Friday , i had english pre-test start
                                 from 9 AM until 6 PM. I did the english pre-test at 10 AM. In the afternoon of the same day 
                                 (4 PM) ,i attended guest speaker session at bangkit youtube channel. The speaker at this session
                                 is Giovanni Sakti Nugraha, Co-founder DeepTechID Foundation. In this session, the speaker talks 
                                 about "Skill that Last a Lifetime". At this week, i also done the assignment given from last
                                 SS ILT session and done a course in coursera.
                                ''')
# Out:
# number of words is 119 ,should be between 100 - 150 words
# words that may be misspelled : ['github', 'sakti', 'afternoon', 'deeptechid', 'hidayaturrahman', 'nugraha']

# %% [markdown]
# ### Week 4

# %%
Mar06 = logbook.write('''Today is the deadline of first mandatory courses in coursera, and i had finished them
                        before the deadline and submit the certificates on google forms''',
                      type_='daily')
# Out:
# number of words is 25 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar07 = logbook.write('''Today i only have one schedule, that is weekly consultation with my mentor, kak Lusi
                        9:00-10:00(WITA) - I attended weekly consultation with mentor''',
                      type_='daily')
# Out:
# number of words is 22 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar08 = logbook.write('''This week i got assignment on google classroom to finish second mandatory courses
                        on coursera. So far i have finished 2 "Data Analytics" courses''',
                      type_='daily')
# Out:
# number of words is 23 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar09 = logbook.write('''Today i continue the "Data Analytics" course , i have finished one more course today
                        ,so i already finish 3 of 6 mandatory courses on "Data Analytics"''',
                      type_='daily')
# Out:
# number of words is 24 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar10 = logbook.write('''Today i have 2 activity from bangkit, one is mandatory and other one is not
                        16:30-17:30(WITA) - I Joined Guest Speaker Session #2 on Youtube
                        19:30-21:30(WITA) - I attended ILT SS 2 about time management''',
                      type_='daily')
# Out:
# number of words is 30 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport4 = logbook.write('''This week , i started "Data Analytics" courses in coursera. So far , i have
                                finished 3 of 6 mandatory courses. I didn't submit the certificates on the google
                                forms yet, i wait to finish all the courses. The weekly consultation this week with mentor, 
                                kak Lusi still ran on the same day and time as last week (Tuesday, 9 am - 10 am). I also got 
                                a session of ILT SS 2 with instructor Muhammad Fikri Kawakibi Huda at Friday 
                                (19:30 - 21:30). It was my very first evening ILT Session. The ILT SS session was 
                                about time management and same as last ILT SS session, we given an assignment on google 
                                classroom.''')
# Out:
# number of words is 104 ,should be between 100 - 150 words
# words that may be misspelled : ['kawakibi', 't', 'huda', 'fikri']

# %% [markdown]
# ### Week 5

# %%
Mar13 = logbook.write('''Last Saturday (11 Mar) i submitted soft skill assignment 2 about time management.
                        Today i have two schedule :
                        14:00-16:00(WITA) - I joined student team meeting 1 on youtube
                        19:30-21:30(WITA) - I attended ILT ML session about Data Analytics
                        ''',
                        type_='daily')
# Out:
# number of words is 33 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar14 = logbook.write('''Today i only have one schedule , that is weekly consultation with mentor from 16:30 to 17:30 (WITA). 
                        Beside that today i also continue my progress on Data Analytics courses on coursera, so far i have
                        finished until 5th course today.
                        ''',
                        type_='daily')
# Out:
# number of words is 38 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar15 = logbook.write('''Today i dont have schedule given by bangkit. So today is a day to focus on 
                        coursera progress. Around 2 PM today, i finished 6th data analytics course.
                        ''',
                        type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar16 = logbook.write('''Today i dont have schedule given by bangkit. So today is a day to focus on 
                        coursera progress. Last week, i already got invitation to ML courses on coursera.
                        So today i enrolled to Math for ML courses and make some progress.
                        ''',
                        type_='daily')
# Out:
# number of words is 42 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar17 = logbook.write('''Today i dont have schedule given by bangkit. So today is a day to focus on 
                        coursera progress. I continue making progress on linear algebra course.
                        ''',
                        type_='daily')
# Out:
# number of words is 26 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport5 = logbook.write('''This week i started "Math for Machine Learning" courses in coursera. So far, I have done 
                                first course (linear algebra) until week2. This week ILT session is ML ILT session, we learn
                                about "Data Analytics" with instructor Moch. Ari Nasichuddin at Monday (19:30 WITA). This
                                week , the weekly consultation with mentor have different schedule. I have my
                                weekly consultation on Tuesday (16:30 WITA). This week i also have  the first student team meeting.
                                I got many information such as dashboard, progress , merch, etc from this meeting. Beside all
                                that i already mentioned i also trying the 5th and 6th course on "Automation with Python" courses.
                                I want to know if i can get all the Python certificates, so far i finished 5th course until week 2 and 
                                6th course until week3.
                                ''')
# Out:
# number of words is 128 ,should be between 100 - 150 words
# words that may be misspelled : ['moch', 'nasichuddin']

# %% [markdown]
# ### Week 6

# %%
Mar20 = logbook.write('''Today i dont have schedule given by bangkit. So today is a day to focus on 
                        coursera progress. Today i continue my progress on linear algebra course.
                        ''',
                        type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar21 = logbook.write('''Today i have finished linear algebra course and continue to multivariative calculus course.
                        I also have weekly consultation with mentor today ,at 16:30 to 17:30.
                        ''',
                        type_='daily')
# Out:
# number of words is 23 ,should be between 20 - 50 words
# words that may be misspelled : ['multivariative']

# %%
Mar23 = logbook.write('''Today i continue my progress on multivariative calculus course. I also have ILT soft skill session today, 
                        14:00 - 16:00 WITA. This session we discus about critical thinking.
                        ''',
                        type_='daily')
# Out:
# number of words is 25 ,should be between 20 - 50 words
# words that may be misspelled : ['multivariative']

# %%
Mar24 = logbook.write('''Today i continue my progress on multivariative calculus course (yesterday too, forget to replace the copy paste). 
                        I also watch guest speaker session on youtube at 16:30 WITA.
                        ''',
                        type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : ['multivariative']

# %%
weeklyReport6 = logbook.write('''This week i started 2nd course on Math for ML courses. On weekends last week , i managed to get
                                Automation with Python certificates. So far i have finished multivariate calculus course until 
                                week3 (as for today,24 Mar). I feel i cant finish the math courses before the deadline. Because
                                i have hard time to understand it and also this week i have Nyepi on Wednesday so cant continue
                                coursera course at that day.I have my weekly consultation this week on Tuesday , 16:30 WITA.
                                Then, i have 3rd session of soft skill ILT that is about critical thinking and problem solving.
                                In the end of the session the instructor, Lalu Triawanri Novianung give us a new assignment.
                                ''')
# Out:
# number of words is 116 ,should be between 100 - 150 words
# words that may be misspelled : ['triawanri', 'lalu', 'nyepi', 'novianung']

# %% [markdown]
# ### Week 7

# %%
Mar27 = logbook.write('''Today i have one schedule, that is ILT ML session with instructor Aldi Fahrezi at 10:00 WITA.
                        I also have finished Multivariate Calculus courses last weekend.
                        ''',
                        type_='daily')
# Out:
# number of words is 25 ,should be between 20 - 50 words
# words that may be misspelled : ['fahrezi', 'aldi']

# %%
Mar28 = logbook.write(''' Today i have weekly consultation as always at 16:30 WITA. I also have done PCA course today at the
                          evening and submitted Math for ML certificate on google classroom.
                        ''',
                        type_='daily')
# Out:
# number of words is 28 ,should be between 20 - 50 words
# words that may be misspelled : ['pca']

# %%
Mar29 = logbook.write('''Today i dont have any meeting schedule by bangkit. My soft skill assignment still haven't finished,
                        so today i focus on doing my soft skill assignment and submit it.
                        ''',
                        type_='daily')
# Out:
# number of words is 30 ,should be between 20 - 50 words
# words that may be misspelled : ['t']

# %%
Mar30 = logbook.write('''Today i dont have any meeting schedule by bangkit. I have finished math for ML courses and
                        soft skill assignment before deadline. Today i started ML specialization courses.
                        ''',
                        type_='daily')
# Out:
# number of words is 28 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Mar31 = logbook.write('''Today i dont have any meeting schedule by bangkit. Today i have finished first courses on
                         ML specialization courses , that is supervised learning courses.
                        ''',
                        type_='daily')
# Out:
# number of words is 24 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport7 = logbook.write('''This week i have finished math for ml courses and started new courses that is ml specialization courses.
                                I also have submitted my soft skill 3rd assignment before the deadline. For the ml specialization courses
                                so far i have finished one course and going to the next course. For the weekly consultation this week, as 
                                usual i have it on Tuesday at 16:30 WITA. Weekly consultation this week is fun for me. I also have 3rd ILT
                                ML session this week on Monday ,10:00 WITA. The ILT ML session is about Introduction to Machine Learning.
                                I also got weekly feedback to mentor this week and already filled the feedback form.
                                ''')
# Out:
# number of words is 108 ,should be between 100 - 150 words
# words that may be misspelled : None

# %% [markdown]
# ### Week 8

# %%
Apr03 = logbook.write('''Today i dont have any mandatory meeting from bangkit, so today i just continue my 2nd course on ML specialization.
                         Also today finally i got invitation for my english class session which is on next Monday.
                        ''',
                        type_='daily')
# Out:
# number of words is 36 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Apr04 = logbook.write('''Today is Tuesday, as usual i have mandatory meeting schedule. That is weekly consultation with mentor at 16:30 WITA.
                         For my coursera progress, it is already week 3, 2nd course.
                        ''',
                        type_='daily')
# Out:
# number of words is 28 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Apr05 = logbook.write('''Today i dont have any mandatory meeting from bangkit, so today i just continue my coursera progress. As for today,
                        i have finished 2nd course on ML specialization courses, so i continue to the last course today.
                        ''',
                        type_='daily')
# Out:
# number of words is 37 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Apr06 = logbook.write('''Today i have mandatory meeting schedule on my calendar, that is ILT SS-4 about adaptability and resilience. I also
                         continue my coursera progress and have finished week 1 3rd course.
                        ''',
                        type_='daily')
# Out:
# number of words is 29 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport8 = logbook.write('''This week, i have weekly consultation as usual on Tuesday 16:30 WITA. On the meeting, we discuss about changing 
                                 the weekly consultation hour because of many people is fasting. I also have ILT soft skill session on Thursday
                                 at 10:00 WITA. The topic is about adaptability and resilience , as usual i already got the assignment on google 
                                 classroom. I plan to make the assignment after i finished ML specialization courses. About my coursera progress
                                 this week i already dive into ML specialization courses. I have finished first course last week and second course
                                 on Wednesday this week. Now i am at third course week 2. I plan to finish third course on Sunday this week before
                                 the deadline.
                                ''')
# Out:
# number of words is 115 ,should be between 100 - 150 words
# words that may be misspelled : None

# %% [markdown]
# ### Week 9

# %%
Apr10 = logbook.write('''Today i have two schedule, that is, student team meeting 2 on 14:00 (WITA) and
                        ILT EN 01 on 16:30 (WITA). About course progress, i have finished Machine learning 
                        specialization yesterday''', type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Apr11 = logbook.write('''Today as usual i have weekly consultation on 16:30 (WITA). In addition , i also joined
                        company expose by DANA and Evomo on youtube, i also joined ML-05 study group today''', type_='daily')
# Out:
# number of words is 29 ,should be between 20 - 50 words
# words that may be misspelled : ['evomo']

# %%
Apr12 = logbook.write('''Forgot to mention on yesterday, i have finished 4th soft skill assignment. Today i have
                        ILT ML 04 on 10:00 (WITA), i also have started Tensorflow developer courses''', type_='daily')
# Out:
# number of words is 26 ,should be between 20 - 50 words
# words that may be misspelled : ['tensorflow']

# %%
Apr13 = logbook.write('''Today i joined company expose by Dicoding, Amati and PukulEnam on 10:00 (WITA).
                        As for today i have finished tensorflow intro course until week 3.''', type_='daily')
# Out:
# number of words is 23 ,should be between 20 - 50 words
# words that may be misspelled : ['tensorflow', 'pukulenam', 'amati']

# %%
Apr14 = logbook.write('''Today i have finished tensorflow intro course, and i continue to the second course on
                        Tensorflow developer courses. As for today i have finished until week 1.''', type_='daily')
# Out:
# number of words is 26 ,should be between 20 - 50 words
# words that may be misspelled : ['tensorflow']

# %%
weeklyReport9 = logbook.write('''This week, on Monday i attended student team meeting 2 on 14:00 WITA then i attended 
                                ILT EN 01 on 16:30 WITA. On Tuesday, i attended company expose by DANA and Evomo on 
                                10:00 WITA then i attended study group on 11:00 WITA and weekly consultation on 
                                16:30 WITA. Wednesday i attended ILT ML 04 on 10:00 WITA, then on Thursday i joined company 
                                expose by Dicoding, Amati and PukulEnam. About coursera progress, i have finished Machine 
                                Learning specialization courses on last Sunday. Then i continue to Tensorflow developer
                                courses on Wednesday and already finished first course this week. And also i have submitted
                                soft skill assignment about "Adaptability and Resilience" this week.''')
# Out:
# number of words is 104 ,should be between 100 - 150 words
# words that may be misspelled : ['evomo', 'tensorflow', 'pukulenam', 'amati']

# %% [markdown]
# ### Week 10

# %%
Apr17 = logbook.write('''On april 16 i completed second course of tensorflow developer courses, today i continue to
                        the third course that is NLP course ''', type_='daily')
# Out:
# number of words is 21 ,should be between 20 - 50 words
# words that may be misspelled : ['nlp', 'tensorflow']

# %%
Apr18 = logbook.write('''Today i continue my progress on coursera in other word continuing NLP course, as for today 
                        i just completed until week 1''', type_='daily')
# Out:
# number of words is 21 ,should be between 20 - 50 words
# words that may be misspelled : ['nlp']

# %%
Apr19 = logbook.write('''Today i didn't continue my coursera progress. Because today i focus on company based capstone
                        proposal''', type_='daily')
# Out:
# number of words is 17 ,should be between 20 - 50 words
# words that may be misspelled : ['t']

# %%
Apr20 = logbook.write('''-''', type_='daily')
# Out:
# number of words is 0 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Apr21 = logbook.write('''-''', type_='daily')
# Out:
# number of words is 0 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport10 = logbook.write('''This week is Eid Al-Fitr mass holiday, i dont have any online meeting like weekly consultation
                                or ILT this week. This week i mostly doing my company capstone proposal. I and my team propose to
                                Dicoding's discussion forum project. This week i also still continue my coursera progress but very 
                                slowly. Last week sunday i have finished second course on Tensorlow developer courses, this week
                                i continue NLP course. As for now , i only finished until week 2 on NLP course. Because this week
                                i'm sick , i can't make big progress on my courses. But now already feeling better, thats why i making
                                the logbook now.''')
# Out:
# number of words is 109 ,should be between 100 - 150 words
# words that may be misspelled : ['nlp', 'm', 's', 'tensorlow', 't', 'fitr']

# %% [markdown]
# ### Week 11

# %%
Apr24 = logbook.write('''-''', type_='daily')
# Out:
# number of words is 0 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Apr25 = logbook.write('''-''', type_='daily')
# Out:
# number of words is 0 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Apr26 = logbook.write('''-''', type_='daily')
# Out:
# number of words is 0 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Apr27 = logbook.write('''Today i report my milestone progress to my supervisor. I also continue my coursera progress to
                        the last course of tensorflow developer courses.''', type_='daily')
# Out:
# number of words is 23 ,should be between 20 - 50 words
# words that may be misspelled : ['tensorflow']

# %%
Apr28 = logbook.write('''Today i fill Bi-weekly feedback from student to mentor, i also still continue my progress on coursera
                        courses. So far i have completed the course until week2.''', type_='daily')
# Out:
# number of words is 28 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport11 = logbook.write('''This week is Eid Al-Fitr mass holiday, i dont have any online meeting like weekly consultation
                                or ILT this week. About my coursera progress, i have finished all tensorflow developer courses as
                                this week. I continue to the next course "structuring ml projects". Also this week, many things happen
                                about capstone. Last week my company based capstone team have submitted the proposal, this week's Monday
                                is the announcement for the selected team. Unfortunately my team didn't selected for company capstone
                                and my team composition does not eligible for product based. So i need to find another team, but...
                                didn't got it until the last day and got a randomized team. Fortunately my random team is all active 
                                and i manage to gather all the member.''')
# Out:
# number of words is 129 ,should be between 100 - 150 words
# words that may be misspelled : ['tensorflow', 's', 't', 'fitr']

# %% [markdown]
# ### Week 12

# %%
May01 = logbook.write('''Yesterday i meet my capstone team for the first time , of course online.The meet purpose is to 
                        know each other first and discussing a bit about topic we will take for the product.
                        About my coursera progress, i still continue the structuring ml project course.''', type_='daily')
# Out:
# number of words is 46 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May02 = logbook.write('''Today i have ILT SS session about "Project Management" on 14:00 WITA. About my coursera progress, 
                        i still on week1 on that course. I cant focus on the course because of capstone.''', type_='daily')
# Out:
# number of words is 31 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May03 = logbook.write('''Today i have weekly consultation on 11:00 WITA. Also today i held meeting with my capstone team twice.
                        First at 12:45 WITA, on this meeting we discuss about ideas we have but not everyone attended the
                        meeting. So i held second meeting today on 20:45 WITA to continue discussion for the idea.''', type_='daily')
# Out:
# number of words is 49 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May04 = logbook.write('''Today i finally passed week1 of course structuring ml project and continue to week2. My capstone
                        team start working on project plan today as we already decided the idea.''', type_='daily')
# Out:
# number of words is 29 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May05 = logbook.write('''Today i held fourth meeting with my capstone team. Today's meeting is to make the project plan
                        together. About my coursera progress, i have finished the structuring ml course today and continue
                        to data and deployment courses.''', type_='daily')
# Out:
# number of words is 38 ,should be between 20 - 50 words
# words that may be misspelled : ['s']

# %%
weeklyReport12 = logbook.write('''This week i have ILT soft skill session on Tuesday at 14:00 WITA about "Project Management".
                                  This ILT session is very related with the capstone, and the assignment is also about our capstone.
                                  I have my weekly consultation on Wednesday at 11:00 WITa. About my coursera progress, this week
                                  i have finished structuring ml project course and continue to TF data and deployment. This week 
                                  i have several meeting with my capstone team. We discuss about ideas we have for the capstone
                                  product and the making the project plan together. Then we submit our project plan just before
                                  the deadline on Friday at 22:00 WITA''')
# Out:
# number of words is 102 ,should be between 100 - 150 words
# words that may be misspelled : ['tf']

# %% [markdown]
# ### Week 13

# %%
May08 = logbook.write('''Today i dont have any meeting , so i focus on my courses. As for today i already finished "Browser
                        Based Models with TensorflowJS" course''', type_='daily')
# Out:
# number of words is 24 ,should be between 20 - 50 words
# words that may be misspelled : ['tensorflowjs']

# %%
May09 = logbook.write('''Today i have ILT ML session at 16:30 WITA. About my course ,i continue to the 
                        second course "Device Based Model with Tensorflow lite" and already done week 1''', type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : ['tensorflow']

# %%
May10 = logbook.write('''Today i have weekly consultation at 11:00 WITA. Today i start making my soft skill #5 assignment
                        and already halfway to finish. Also i finished week2 of second course today.''', type_='daily')
# Out:
# number of words is 28 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May11 = logbook.write('''Today i have finished my soft skill assignment and submitted it. I also have finished the second 
                        course of TF Data & Deployment today.''', type_='daily')
# Out:
# number of words is 23 ,should be between 20 - 50 words
# words that may be misspelled : ['tf']

# %%
May12 = logbook.write('''Today i dont have any meeting session so i focus to continue my third course on TF
                        Data & Deployment and i already finished until week3''', type_='daily')
# Out:
# number of words is 25 ,should be between 20 - 50 words
# words that may be misspelled : ['tf']

# %%
weeklyReport13 = logbook.write('''This week i have ILT ML session on Tuesday at 16:30 WITA. The ILT session was about
                                advanced technique in machine learning, such as CNN, NLP and Time Series. I have weekly
                                consultation this week on Wednesday at 11:00 WITA. This week my coursera progress already
                                at the last courses batch that is Tensorflow Data Pipelines and Deployments. On Monday 
                                this week i finished the first course, on Thursday i finished the second course. Now i am
                                already at the week4 of the third course. This week i also have made and submit my soft skill
                                #5 assignment. The assignment was about my capstone, so i tell about what i do on the last
                                week, like i discuss about the idea of our capstone product first then we made a project plan.
                                About my project plan, glad it is approved by bangkit team.''')
# Out:
# number of words is 140 ,should be between 100 - 150 words
# words that may be misspelled : ['nlp', 'tensorflow', 'cnn']

# %% [markdown]
# ### Week 14

# %%
May15 = logbook.write('''Today we have student team meeting at 14:00 WITA, and i also held meeting with my capstone team at
                        20:00 WITA to discuss about datasets for training our model. ''', type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : ['datasets']

# %%
May16 = logbook.write('''Today i have ILT soft skill session at 16:30 WITA. This session was about Professional Communication
                        and Networking. Where in this session i discover that my communication style is "Analytical"''', type_='daily')
# Out:
# number of words is 29 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May17 = logbook.write('''Today i dont have any meeting nor ILT session. As i have finished all the mandatory courses,
                        today i just use what i have learn by participating Kaggle competitions''', type_='daily')
# Out:
# number of words is 29 ,should be between 20 - 50 words
# words that may be misspelled : ['kaggle']

# %%
May18 = logbook.write('''Today i held meeting with my capstone team, we discuss further about dataset. We also discuss
                        about which virtual machine to use on google cloud''', type_='daily')
# Out:
# number of words is 25 ,should be between 20 - 50 words
# words that may be misspelled : ['dataset']

# %%
May19 = logbook.write('''Today i have weekly consultation on 15:00 WITA. I also continue working on my capstone progress,
                        i found interesting article that was about the same topic with my capstone idea''', type_='daily')
# Out:
# number of words is 29 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport14 = logbook.write('''Last week i write that im at week4 on third course, but after that i continue the fourth course on Saturday
                                and Sunday. I manage to finish the fourth course until Sunday (approximately 2 days). On Monday this week,
                                we have student team meeting on 14:00 WITA. They announce many things about post bangkit activity. In the same
                                day, i have meeting with my capstone team to discuss our project starting. On Tuesday i have ILT soft skill
                                session at 16:30 WITA and the session was about "Professional Communication and Networking". On Friday , i 
                                have weekly consultation with mentor at 15:00 WITA. Since i have finished all mandatory course, my activity
                                this week just for capstone. Approximately, my capstone progress have reached 10% to finish.''')
# Out:
# number of words is 120 ,should be between 100 - 150 words
# words that may be misspelled : None

# %% [markdown]
# ### Week 15

# %%
May22 = logbook.write('''Today i got announcement email for my capstone advisors and i contacted them. 
                        I also start doing my soft skill #6 assignment.''', type_='daily')
# Out:
# number of words is 21 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May23 = logbook.write('''Today i dont have any meeting schedule so i continue my soft skill assignment #6 
                        until finish then uploaded the video to youtube and submitted it to classroom. ''', type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May24 = logbook.write('''Today i have weekly consultation with mentor at 11:00 WITA. I asked about how 
                        to fill capstone working doc because tomorow we will have capstone mentoring session.''', type_='daily')
# Out:
# number of words is 26 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May25 = logbook.write('''Today i have capstone mentoring session with my second advisor at 14:00 WITA.
                         After that i have machine learning ILT session at 16:30 WITA.''', type_='daily')
# Out:
# number of words is 22 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May26 = logbook.write('''Today i report my learning progress to my supervisor and submitted the 
                        evidence to the google form. I also have ILT english session at 19:30 WITA.''', type_='daily')
# Out:
# number of words is 25 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport15 = logbook.write('''This week bangkit has announced who are my capstone advisors. I has meet with them via
                                google meet. On Thursday at 14:00 WITA i have mentoring session with my second advisor 
                                Rendy Aries Fajrin. On Sunday at 15:00 WITA i have mentoring session with my first advisor
                                Edi Darmawansah. On these two mentoring sessions we discuss about our product value proposition
                                because my team still dont understand about it. This week i have ILT machine learning session
                                on Thursday at 16:30 WITA and ILT english session on Friday at 19:30 WITA. I have my weekly 
                                consultation on Wednesday at 11:00 WITA. I also already done my soft skill assignment about
                                professional communication this week.''')
# Out:
# number of words is 109 ,should be between 100 - 150 words
# words that may be misspelled : ['fajrin', 'darmawansah', 'rendy']

# %% [markdown]
# ### Week 16

# %%
May29 = logbook.write('''Today i dont have any schedule but capstone mid checkpoint deadline
                        soon so i start creating progress report doc with my team.''', type_='daily')
# Out:
# number of words is 22 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May30 = logbook.write('''Today i have one meeting schedule that is ILT soft skill session at
                        14:00 WITA. The session about personal branding and interview.''', type_='daily')
# Out:
# number of words is 21 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
May31 = logbook.write('''Today i have one meeting schedule that is  weekly consultation with
                        mentor at  11:00 WITA. Today also the deadline of mid checkpoint so
                        i submitted the form today.''', type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun01 = logbook.write('''Today i held meeting with all my capstone team. We discuss about
                        our product development progress, schedule and final deliverables''', type_='daily')
# Out:
# number of words is 20 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun02 = logbook.write('''Today i have weekly mentoring session with my capstone advisor Rendy Aries Fajrin.
                        We discuss about our progress and final deliverables.''', type_='daily')
# Out:
# number of words is 21 ,should be between 20 - 50 words
# words that may be misspelled : ['rendy', 'fajrin']

# %%
weeklyReport16 = logbook.write('''This week i have several meeting schedule and working on capstone progress.
                                On monday , i start to make report document for the mid-checkpoint capstone
                                activity. Our progress was about 40% overall because we didn't start to make
                                final deliverables yet. On tuesday i have ILT SS session at 14:00 WITA. The session
                                was lead by instructor Risca Tresmianti Suarna. On wednesday i have weekly 
                                consultation at 11:00 WITA and also submitted mid-checkpoint for capstone. 
                                On thursday, i held meeting with all my team member to discuss about our
                                capstone progress , rescheduling our schedule, and start making our final 
                                deliverables. On friday, my advisor as us to held weekly mentoring session with him
                                so i held it at 16:30 WITA. We ask something that we dont understand about the
                                presentation slide for final deliverables.''')
# Out:
# number of words is 132 ,should be between 100 - 150 words
# words that may be misspelled : ['suarna', 't', 'tresmianti', 'risca']

# %% [markdown]
# ### Week 17

# %%
Jun05 = logbook.write('''Today i dont have any meeting with capstone team, but i focus on working
                        for our final application product so we can submit final deliverables before due.''', type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun06 = logbook.write('''Today i dont have any meeting with capstone team but focus working on capstone.
                        I also have submitted soft skill #7 assignment as for today.''', type_='daily')
# Out:
# number of words is 24 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun07 = logbook.write('''Today i have weekly consultation with my mentor, kak lusi. We mostly talk about
                        problem we have on our capstone product.''', type_='daily')
# Out:
# number of words is 21 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun08 = logbook.write('''Today i dont have any meeting with capstone team, but i focus on working
                        for our final application product so we can submit final deliverables before due.''', type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun09 = logbook.write('''Today i plan a weekly mentoring session with my advisor kak Rendy at
                        22:00 WITA. But unfortunately he cant join because have problem with his internet 
                        so i reschedule it.''', type_='daily')
# Out:
# number of words is 29 ,should be between 20 - 50 words
# words that may be misspelled : ['rendy']

# %%
weeklyReport17 = logbook.write('''During this week, my progress in the capstone project was as follows. On Monday, I focused on working on our final application to meet the submission deadline. On Tuesday, without any team meetings, I successfully completed the soft skill #7 assignment. On Wednesday, I had a discussion with my mentor about the challenges in our project. On Thursday, I continued to concentrate on the development of the final application. Unfortunately, the Friday meeting with my advisor had to be rescheduled due to internet issues. Overall, this week showed good progress, with a focus on individual work, mentor discussions, and necessary adjustments. This logbook meets the word count requirements with a total of 103 words.''')
# Out:
# number of words is 112 ,should be between 100 - 150 words
# words that may be misspelled : None

# %% [markdown]
# ### Week 18

# %%
Jun12 = logbook.write('''Today i have mandatory session to attend, that is student team meeting 4. On capstone 
                        progress, we just need finishing to mobile application and then make presentation slide.''', type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun13 = logbook.write('''Today i have mentoring session with my advisor about presentation slide. We now focus on
                        creating presentation slide for ten-minute video presentation.''', type_='daily')
# Out:
# number of words is 23 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun14 = logbook.write('''Today i focus on making final deliverables for capstone. I assign each my team member
                        to make specific part of the final deliverables.''', type_='daily')
# Out:
# number of words is 23 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun15 = logbook.write('''Today i focus on creating presentation video for final deliverables capstone. 
                        I assign each my team member to make presentation video of specific part they 
                        make yesterday.''', type_='daily')
# Out:
# number of words is 27 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun16 = logbook.write('''Today i focus editing our ten-minute presentation video and submitted every 
                        capstone final deliverables before deadline. I hope i get good result.''', type_='daily')
# Out:
# number of words is 23 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport18 = logbook.write('''This week i have few meeting schedule that is student team meeting, weekly consultation,
                                capstone mentoring. On Monday i attend student team meeting at 14:00 WITA. On Tuesday
                                i held mentoring session with my advisor Rendy at 13:30 WITA. On Thursday i have weekly
                                consultation at 16:00 WITA. This week i mostly doing my capstone final deliverables.
                                Our app development has finished 100% based on project plan as for Tuesday. After that
                                we focus on making project brief, presentation slide and ten-minute presentation video.
                                We are doing our best to make the final deliverables, our advisor kak Rendy also give
                                us a positive remarks on our project brief. I have submitted our final deliverables on Friday
                                before the deadline time.''')
# Out:
# number of words is 117 ,should be between 100 - 150 words
# words that may be misspelled : ['rendy']

# %% [markdown]
# ### Week 19

# %%
Jun19 = logbook.write('''Today i and my capstone team focus practicing our capstone presentation because
                        tomorow we will have our presentation.''', type_='daily')
# Out:
# number of words is 18 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun20 = logbook.write('''Today i have capstone peer review presentation at 14:00 WITA. We already practiced
                        our presentation yesterday so our presentation run well i think.''', type_='daily')
# Out:
# number of words is 22 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun21 = logbook.write('''Today i only have a short weekly consultation at 11:00 WITA. I also start making my
                        final report for kampus merdeka today.''', type_='daily')
# Out:
# number of words is 21 ,should be between 20 - 50 words
# words that may be misspelled : ['merdeka', 'kampus']

# %%
Jun22 = logbook.write('''Since capstone finally done, i start to focus on my extra course. Also 
                        today i have ILT EN session at 19:30 WITA.''', type_='daily')
# Out:
# number of words is 21 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
Jun23 = logbook.write('''Today i dont have mandatory meeting so i continue my extra course on dicoding
                        while waiting the announcement for capstone to 65 team.''', type_='daily')
# Out:
# number of words is 22 ,should be between 20 - 50 words
# words that may be misspelled : None

# %%
weeklyReport19 = logbook.write('''This week i have capstone peer review presentation, weekly consultation and ILT
                                EN session about "Bussines Presentation". Before our presentation day, i held
                                a meeting with my capstone team to practice our presentation on Monday. We did 
                                it in two session at 14:00 and 21:00 WITA. Then, on Tuesday is the presentation day. Beside
                                our presentation we also review other team presentation. On Wednesday i have
                                weekly consultation at 11:00 WITA. Then, on Thursday i have ILT EN session about 
                                "Bussines Presentation" at 19:30 WITA. Beside that i also start making my final
                                report for kampus merdeka and continue my extra course on dicoding. The final project
                                submission on dicoding so strict. The top 65 capstone team also have been announced, 
                                sadly our team didnt get it.''')
# Out:
# number of words is 122 ,should be between 100 - 150 words
# words that may be misspelled : ['kampus', 'merdeka', 'didnt']

# %% [markdown]
# ### Week 20

# %%
Jun26 = logbook.write(''' ''', type_='daily')

# %%
Jun27 = logbook.write(''' ''', type_='daily')

# %%
Jun28 = logbook.write(''' ''', type_='daily')

# %%
Jun29 = logbook.write(''' ''', type_='daily')

# %%
Jun30 = logbook.write(''' ''', type_='daily')

# %%
weeklyReport20 = logbook.write(''' ''')
